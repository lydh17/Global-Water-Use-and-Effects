# %% [markdown]
# # Feeder 3.1
# ## Step 1: Setting up the proper tools
# ### In order to access the data set, link the Colab notebook to a personalized google drive. This is doene by importing google colab and drive and then mounting the drive. In order to do this, code the following.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### This code results in a pop up that asks for permission to let Colab have access to the google drive. Permit the access by clicking the yes button that is supplied by the google drive popup.
# ### The next step is to import the pandas package that allows for many different functions within the python notebook. The following code imports the necessary packages.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Step 2: Connecting the csv dataset to the Colab notebook
# ### In order to access the desired raw dataset, make a data frame of the file. In order to do this, write the following code that utilizes a file pathway.

# %%
df=pd.read_csv('/content/gdrive/MyDrive/AQUASTAT Dissemination System (1).csv')

# %% [markdown]
# ### The previous code creates a data frame that can be used for manipulation using the pandas package previously imported.
# ### It uses a read function to turn a particular file into a data frame. In order to make the desired file a data frame, find the file within the imported drive and copy the pathway by right-clicking and selecting the option copy pathway. Then hit control v buttons to paste the pathway within the orange apostrophe marks.
# ## Step 3: Compile a new subset
# ### In order to narrow down data that will be useful for future analysis, filter out columns that are not necessary. The first step is to look at the different columns. Call the column names using the following code.

# %%
df.columns
# Out:
# Index(['VariableGroup', 'Subgroup', 'Variable', 'Area', 'Year', 'Value',
#        'Unit', 'Symbol', 'IsAggregate'],
#       dtype='object')

# %% [markdown]
# ### To get a better look at the way the data frame is structured look at the first 5 and last 5 data entries using the data frame head and tail functions that are used in the following code.

# %%
df.head()
# Out:
#             VariableGroup                                  Subgroup  \
# 0  Environment and health  Access to improved drinking water source
# 1  Environment and health  Access to improved drinking water source
# 2  Environment and health  Access to improved drinking water source
# 3  Environment and health  Access to improved drinking water source
# 4  Environment and health  Access to improved drinking water source
#
#                                             Variable         Area  Year  \
# 0  Rural population with access to safe drinking-...  Afghanistan  2020
# 1  Rural population with access to safe drinking-...      Albania  2020
# 2  Rural population with access to safe drinking-...      Algeria  2020
# 3  Rural population with access to safe drinking-...      Andorra  2020
# 4  Rural population with access to safe drinking-...       Angola  2020
#
#    Value Unit Symbol  IsAggregate
# 0   47.0    %      I        False
# 1   95.2    %      I        False
# ...

# %%
df.tail()
# Out:
#       VariableGroup                    Subgroup                     Variable  \
# 12906     Water use  Water withdrawal by source  Total freshwater withdrawal
# 12907     Water use  Water withdrawal by source  Total freshwater withdrawal
# 12908     Water use  Water withdrawal by source  Total freshwater withdrawal
# 12909     Water use  Water withdrawal by source  Total freshwater withdrawal
# 12910     Water use  Water withdrawal by source  Total freshwater withdrawal
#
#                Area  Year        Value          Unit Symbol  IsAggregate
# 12906  Western Asia  2020   185.978140  10^9 m3/year      E         True
# 12907         World  2020  3895.898872  10^9 m3/year      E         True
# 12908         Yemen  2020     3.565000  10^9 m3/year      I        False
# 12909        Zambia  2020     1.572000  10^9 m3/year      I        False
# 12910      Zimbabwe  2020     3.771382  10^9 m3/year      I        False

# %% [markdown]
# ### Since the first column isn't necessary for future questions, as well as the last two columns, for now, filter them out of the subset. You can do this by executing the following code.

# %%
df.iloc[:,1:7]
# Out:
#                                        Subgroup  \
# 0      Access to improved drinking water source
# 1      Access to improved drinking water source
# 2      Access to improved drinking water source
# 3      Access to improved drinking water source
# 4      Access to improved drinking water source
# ...                                         ...
# 12906                Water withdrawal by source
# 12907                Water withdrawal by source
# 12908                Water withdrawal by source
# 12909                Water withdrawal by source
# 12910                Water withdrawal by source
#
#                                                 Variable          Area  Year  \
# 0      Rural population with access to safe drinking-...   Afghanistan  2020
# 1      Rural population with access to safe drinking-...       Albania  2020
# 2      Rural population with access to safe drinking-...       Algeria  2020
# ...

# %% [markdown]
# ### The previous code uses a iloc function, which locates integer values and reports them back. The items in the [] are indexes that provide information on when the new output should start and stop within the dataset. A ':' in the first half of the brackets is used to suggest all rows while in the second half is used to suggest all columns. The above example shows all rows being included while only columns with indexes 2-7 are included. Indexes start at zero as the first spot rather than 1. The last index is one more than the final spot it will show! Compare the excel numbers to the columns above to compare and understand the indices.

# %% [markdown]
# ### Having access to almost 13,000 rows is too many. Focus on the variables that are the focus of the analysis. First look for where in the excel sheet where the dependency ratio of total renewable water resources starts and finishes remebering the index rule.  Take note of the range that these variables cover. Then use the iloc function to filter out all but the rows corresponding to the variables. Use the same index for the column of the iloc function.

# %%
df.iloc[6406:6599,1:7]
# Out:
#                              Subgroup          Variable  \
# 6406  Total renewable water resources  Dependency ratio
# 6407  Total renewable water resources  Dependency ratio
# 6408  Total renewable water resources  Dependency ratio
# 6409  Total renewable water resources  Dependency ratio
# 6410  Total renewable water resources  Dependency ratio
# ...                               ...               ...
# 6594  Total renewable water resources  Dependency ratio
# 6595  Total renewable water resources  Dependency ratio
# 6596  Total renewable water resources  Dependency ratio
# 6597  Total renewable water resources  Dependency ratio
# 6598  Total renewable water resources  Dependency ratio
#
#                                     Area  Year      Value Unit
# 6406                         Afghanistan  2020  28.722600    %
# 6407                             Albania  2020  10.927152    %
# 6408                             Algeria  2020   3.599897    %
# ...

# %% [markdown]
# ### This snippet of the raw data is ready to be added to the refined subset. In order to do this, make a new data set called df1 and store this data. In order to do this, write the same code as before but assign df1 = before it.

# %%
df1 = df.iloc[6406:6599, 1:7]

# %% [markdown]
# ### Repeat the process for the variable regarding agricultural water withdrawal in the pressure of water resources subgroup by using the iloc function. First check to make sure that the correct data was grabbed hten assign it to df2.

# %%
df.iloc[7592:7790,1:7]
# Out:
#                          Subgroup  \
# 7592  Pressure on water resources
# 7593  Pressure on water resources
# 7594  Pressure on water resources
# 7595  Pressure on water resources
# 7596  Pressure on water resources
# ...                           ...
# 7785  Pressure on water resources
# 7786  Pressure on water resources
# 7787  Pressure on water resources
# 7788  Pressure on water resources
# 7789  Pressure on water resources
#
#                                                Variable                 Area  \
# 7592  Agricultural water withdrawal as % of total re...          Afghanistan
# 7593  Agricultural water withdrawal as % of total re...              Albania
# 7594  Agricultural water withdrawal as % of total re...              Algeria
# 7595  Agricultural water withdrawal as % of total re...               Angola
# 7596  Agricultural water withdrawal as % of total re...  Antigua and Barbuda
# ...                                                 ...                  ...
# ...

# %%
df2 = df.iloc[7592:7790,1:7]

# %% [markdown]
# ### Repeat the process one last time regarding the varaible consisting of the number of municipal wastewater treatment facilities.

# %%
df.iloc[9392:9474,1:7]
# Out:
#         Subgroup                                           Variable  \
# 9392  Wastewater  Number of municipal wastewater treatment facil...
# 9393  Wastewater  Number of municipal wastewater treatment facil...
# 9394  Wastewater  Number of municipal wastewater treatment facil...
# 9395  Wastewater  Number of municipal wastewater treatment facil...
# 9396  Wastewater  Number of municipal wastewater treatment facil...
# ...          ...                                                ...
# 9469  Wastewater  Number of municipal wastewater treatment facil...
# 9470  Wastewater  Number of municipal wastewater treatment facil...
# 9471  Wastewater  Number of municipal wastewater treatment facil...
# 9472  Wastewater  Number of municipal wastewater treatment facil...
# 9473  Wastewater  Number of municipal wastewater treatment facil...
#
#                                                    Area  Year    Value Unit
# ...

# %%
df3 = df.iloc[9392:9474,1:7]

# %% [markdown]
# ## Step 4: Put the dataframes together
# ### Put all the data frames into one list using hte following code. Lists are multiple objects in one variable like seen below.

# %%
dfAll = [df1, df2, df3]

# %% [markdown]
# ### Since all the frames are in the same variable, use the concat function from pandas to put them into the same data fram called dfFinal  using the following code.

# %%
dfFinal= pd.concat(dfAll)

# %% [markdown]
# ### Convert the final dataframe into a csv file using the following code.

# %%
dfFinal.to_csv('dfFinal.csv')
